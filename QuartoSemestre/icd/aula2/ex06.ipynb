# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr, spearmanr


x = np.matrix([[10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5], [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68], [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74], [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73], [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8], [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]])

# %%
for i in x:
    print("Média: ")
    print(i.mean())
    print("Variância: ")
    print(i.var())
    print("Pearson")
    N = 100
    X = np.linspace(-1,1, N)
    erro = np.random.uniform(-1,1,N) # ruído a ser incluído na relação linear.
    for sigma in np.arange(0,1,0.2):
        Y = 0.5*X + erro*sigma
        plt.plot(X,Y, 'ro')
        corr, p_value = pearsonr(X, Y) # calcula a correlação
        corr = int(corr*100)/100
        string = 'corr = '+ str(corr)
        plt.xlim(-1.5,1.5)
        plt.ylim(-2, 2)
        plt.text(0.6,1.7, string, fontsize=15)
        plt.show(True)
    print('Spearman')
    N = 100
    X = np.linspace(-1,1, N)
    erro = np.random.uniform(-1,1,N) # ruído a ser incluído na relação linear.
    for sigma in np.arange(0,1,0.2):
        Y = 0.5*X + erro*sigma
        plt.plot(X,Y, 'ro')
        orrs, p_values = spearmanr(X, Y)
        corr = int(corr*100)/100
        string = 'corr = '+ str(corr)
        plt.xlim(-1.5,1.5)
        plt.ylim(-2, 2)
        plt.text(0.6,1.7, string, fontsize=15)
        plt.show(True)
    print()
# Out:
# Média:
# 9.0
# Variância:
# 10.0
# Pearson
# Spearman
# Média:
# 7.500909090909093
# Variância:
# 3.7520628099173554
# Pearson
# Spearman
# Média:
# 7.50090909090909
# Variância:
# 3.752390082644628
# Pearson
# Spearman
# Média:
# 7.5
# Variância:
# 3.747836363636364
# Pearson
# Spearman
# Média:
# 9.0
# Variância:
# 10.0
# Pearson
# Spearman
# Média:
# 7.500909090909091
# Variância:
# 3.7484082644628103
# Pearson
# Spearman
